# %%
# %pylab --no-import-all inline

from utils import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mnist = load_datasets()

# %% [markdown]
# # 1. Original MNIST

# %%
show_samples(mnist.original.train, mnist.labels.train, 12, random_state=42)

# %% [markdown]
# # 2. Light dirty MNIST

# %%
show_samples(mnist.dirty_light.train, mnist.labels.train, 12, random_state=42)

# %% [markdown]
# # 3. Dirty hard MNIST

# %%
show_samples(mnist.dirty_hard.train, mnist.labels.train, 12, random_state=42)

# %% [markdown]
# # Задачи
# - распознование по кускам
# - обучение по dirty
# - зависимость точности алгоритма от уровня "клякс"
